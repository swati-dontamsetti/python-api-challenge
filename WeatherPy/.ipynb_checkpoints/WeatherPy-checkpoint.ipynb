# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

print("Beginning Data Retrieval")
print("-----------------------------")
count = 0

for city in cities:
    # Build query URL
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Get weather data
    weather_json = requests.get(query_url).json()
    
    # increase count
    count += 1

    try:
        name = weather_json["name"]
        print(f"Processing Record {count} of {len(cities)}: {name}")
    except:
        print("City not found. Skipping...")
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 611: Rikitea
# Processing Record 2 of 611: Christchurch
# City not found. Skipping...
# Processing Record 4 of 611: Punta Arenas
# Processing Record 5 of 611: Hithadhoo
# Processing Record 6 of 611: Chokurdakh
# Processing Record 7 of 611: Ponta do Sol
# Processing Record 8 of 611: Pangnirtung
# City not found. Skipping...
# Processing Record 10 of 611: Amapala
# Processing Record 11 of 611: New Norfolk
# Processing Record 12 of 611: Arraial do Cabo
# Processing Record 13 of 611: Faanui
# Processing Record 14 of 611: Klaksvík
# Processing Record 15 of 611: Kismayo
# Processing Record 16 of 611: Pimenta Bueno
# Processing Record 17 of 611: Hobart
# Processing Record 18 of 611: Nyurba
# Processing Record 19 of 611: Kure
# Processing Record 20 of 611: Bhūm
# Processing Record 21 of 611: Hermanus
# Processing Record 22 of 611: Meulaboh
# Processing Record 23 of 611: Busselton
# Processing Record 24 of 611: Gijang
# Processing Record 25 of 611: Talnakh
# Processing Record 26 of 611: Yellowknife
# Processing Record 27 of 611: Bambous Virieux
# Processing Record 28 of 611: Vaini
# Processing Record 29 of 611: Viedma
# Processing Record 30 of 611: Ventspils
# Processing Record 31 of 611: Bilibino
# Processing Record 32 of 611: Atuona
# Processing Record 33 of 611: Cape Town
# Processing Record 34 of 611: Padang
# Processing Record 35 of 611: Yumen
# Processing Record 36 of 611: Saint Paul Harbor
# Processing Record 37 of 611: Khatanga
# Processing Record 38 of 611: Albany
# Processing Record 39 of 611: Walvis Bay
# Processing Record 40 of 611: Narsaq
# Processing Record 41 of 611: Samagaltay
# Processing Record 42 of 611: Te Anau
# Processing Record 43 of 611: Ushuaia
# Processing Record 44 of 611: Cherskiy
# Processing Record 45 of 611: Ürümqi
# Processing Record 46 of 611: Butaritari
# Processing Record 47 of 611: Bandarbeyla
# Processing Record 48 of 611: Buala
# Processing Record 49 of 611: Tura
# Processing Record 50 of 611: Tessalit
# Processing Record 51 of 611: Geraldton
# Processing Record 52 of 611: Mar del Plata
# Processing Record 53 of 611: Dunedin
# Processing Record 54 of 611: Ishigaki
# Processing Record 55 of 611: Lompoc
# Processing Record 56 of 611: Hambantota
# Processing Record 57 of 611: Kapaa
# Processing Record 58 of 611: Juegang
# Processing Record 59 of 611: Praia da Vitória
# Processing Record 60 of 611: George Town
# Processing Record 61 of 611: Pratāpgarh
# City not found. Skipping...
# Processing Record 63 of 611: Jinchang
# Processing Record 64 of 611: Semporna
# Processing Record 65 of 611: Saint-Pierre
# Processing Record 66 of 611: Bundaberg
# Processing Record 67 of 611: Yangi Marg`ilon
# Processing Record 68 of 611: Kyra
# Processing Record 69 of 611: Thinadhoo
# Processing Record 70 of 611: Brusyliv
# Processing Record 71 of 611: Anadyr
# City not found. Skipping...
# Processing Record 73 of 611: Mataura

# City not found. Skipping...
# City not found. Skipping...
# Processing Record 585 of 611: Deputatsky
# Processing Record 586 of 611: Batemans Bay
# Processing Record 587 of 611: Nome
# Processing Record 588 of 611: Nicoya
# Processing Record 589 of 611: Okha
# Processing Record 590 of 611: Asău
# Processing Record 591 of 611: Kresttsy
# Processing Record 592 of 611: Kimitsu
# Processing Record 593 of 611: Mount Isa
# Processing Record 594 of 611: Lhokseumawe
# Processing Record 595 of 611: Koulikoro
# Processing Record 596 of 611: Collie
# Processing Record 597 of 611: Sangar
# Processing Record 598 of 611: Florida
# City not found. Skipping...
# Processing Record 600 of 611: Port Hedland
# Processing Record 601 of 611: Puerto Escondido
# Processing Record 602 of 611: Manacapuru
# City not found. Skipping...
# Processing Record 604 of 611: La Libertad
# Processing Record 605 of 611: Ponta Delgada
# Processing Record 606 of 611: Jiujiang
# Processing Record 607 of 611: Cairns
# Processing Record 608 of 611: Los Llanos de Aridane
# Processing Record 609 of 611: Tsiroanomandidy
# Processing Record 610 of 611: Pentecoste
# Processing Record 611 of 611: Luwingu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# read csv file
df = pd.read_csv(output_data_file)

# view number of items per column
df.count()
# Out:
# City_ID       548
# City          548
# Cloudiness    548
# Country       544
# Date          548
# Humidity      548
# Lat           548
# Lng           548
# Max Temp      548
# Wind Speed    548
# dtype: int64

# %%
# print data frame
df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# 0     39.51     37.50        7.16
# 1     57.70     78.80       11.41
# 2    -69.36     22.20        2.37
# 3    112.04     44.60        4.47
# 4     18.42     55.99        8.05
# ..      ...       ...         ...
# 543   36.66     80.60        8.05
# 544 -104.61     84.20       16.11
# 545    0.71     61.00        8.05
# 546  132.56     49.74        2.68
# 547  109.18     55.86        2.84
#
# [548 rows x 10 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# create scatter plot
plt.scatter(df["Lat"], df["Max Temp"])

# add labels and title
plt.title("City Latitude vs. Max Temperature (03/16/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# add grid lines
plt.grid()

# show and save pic
plt.show()
plt.savefig("../output_data/1LatvTemp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# create scatter plot
plt.scatter(df["Lat"], df["Humidity"])

# add labels and title
plt.title("City Latitude vs. Humidity (03/16/2020)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# add grid lines
plt.grid()

# show and save pic
plt.show()
plt.savefig("../output_data/2LatvHumid.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# create scatter plot
plt.scatter(df["Lat"], df["Cloudiness"])

# add labels and title
plt.title("City Latitude vs. Cloudiness (03/16/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# add grid lines
plt.grid()

# show and save pic
plt.show()
plt.savefig("../output_data/3LatvCloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# create scatter plot
plt.scatter(df["Lat"], df["Wind Speed"])

# add labels and title
plt.title("City Latitude vs. Wind Speed (03/16/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# add grid lines
plt.grid()

# show and save pic
plt.show()
plt.savefig("../output_data/4LatvWind.png")

# %% [markdown]
# ## Linear Regression

# %%
# x axis for noth and souht
nx_values = []
sx_values = []

# y axis for temp
ny_values = []
sy_values = []

# y axis for humidity
nhy_values = []
shy_values = []

# y axis for cloudiness
ncy_values = []
scy_values = []

# y axis for wind speed
nwy_values = []
swy_values = []

# append arrays
for index in df["City_ID"]:
    if df["Lat"][index] >= 0:
        nx_values.append(df["Lat"][index])
        ny_values.append(df["Max Temp"][index])
        nhy_values.append(df["Humidity"][index])
        ncy_values.append(df["Cloudiness"][index])
        nwy_values.append(df["Wind Speed"][index])
    if df["Lat"][index] < 0:
        sx_values.append(df["Lat"][index])
        sy_values.append(df["Max Temp"][index])
        shy_values.append(df["Humidity"][index])
        scy_values.append(df["Cloudiness"][index])
        swy_values.append(df["Wind Speed"][index])
        
# convert all array values from float to integer
nx_values = np.array(nx_values, dtype = "int")
sx_values = np.array(sx_values, dtype = "int")
ny_values = np.array(ny_values, dtype = "int")
sy_values = np.array(sy_values, dtype = "int")
nhy_values = np.array(nhy_values, dtype = "int")
shy_values = np.array(shy_values, dtype = "int")
ncy_values = np.array(ncy_values, dtype = "int")
scy_values = np.array(scy_values, dtype = "int")
nwy_values = np.array(nwy_values, dtype = "int")
swy_values = np.array(swy_values, dtype = "int")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(nx_values, ny_values)
regress_values = nx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(nx_values, ny_values)
plt.plot(nx_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Latitude Cities vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8129478829517947

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(sx_values, sy_values)
regress_values = sx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(sx_values, sy_values)
plt.plot(sx_values,regress_values,"r-")
plt.annotate(line_eq,(-30,40),fontsize=15,color="red")
plt.title("Southern Latitude Cities vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.7587165111438969

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(nx_values, nhy_values)
regress_values = nx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(nx_values, nhy_values)
plt.plot(nx_values,regress_values,"r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")
plt.title("Northern Latitude Cities vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.10332208236414549

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(sx_values, shy_values)
regress_values = sx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(sx_values, shy_values)
plt.plot(sx_values,regress_values,"r-")
plt.annotate(line_eq,(-50,110),fontsize=15,color="red")
plt.title("Southern Latitude Cities vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.14594093320524656

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(nx_values, ncy_values)
regress_values = nx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(nx_values, ncy_values)
plt.plot(nx_values,regress_values,"r-")
plt.annotate(line_eq,(45,60),fontsize=15,color="red")
plt.title("Northern Latitude Cities vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.08736153158454596

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(sx_values, scy_values)
regress_values = sx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(sx_values, scy_values)
plt.plot(sx_values,regress_values,"r-")
plt.annotate(line_eq,(-45,30),fontsize=15,color="red")
plt.title("Southern Latitude Cities vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.21658483275635929

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(nx_values, nwy_values)
regress_values = nx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(nx_values, nwy_values)
plt.plot(nx_values,regress_values,"r-")
plt.annotate(line_eq,(45,21),fontsize=15,color="red")
plt.title("Northern Latitude Cities vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.10655019773275555

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(sx_values, swy_values)
regress_values = sx_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(sx_values, swy_values)
plt.plot(sx_values,regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.title("Southern Latitude Cities vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.321899328000621
